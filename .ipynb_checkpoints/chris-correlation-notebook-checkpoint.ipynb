# %% [markdown]
# # World Happiness Report correlation analysis

# %%
import csv
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib as mp
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import scipy.stats
from mlxtend.preprocessing import minmax_scaling

# %%
df = pd.read_csv(r'C:\Users\dasfl\Downloads\WorldHappiness\2019.csv')
df2 = pd.read_csv(r'C:\Users\dasfl\Downloads\tax_as_pc_gdp.csv')
df3 = pd.read_csv(r'C:\Users\dasfl\Downloads\8827699-f5cac3d42d16b78348610fc4ec301e9234f82821\countries_codes_and_coordinates.csv')

# %%
df.head(20)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# ...

# %%
df2.head()
# Out:
#   LOCATION  INDICATOR SUBJECT MEASURE FREQUENCY  TIME   Value  Flag Codes
# 0      AUS  TAXINCOME     TOT  PC_GDP         A  2015  11.546         NaN
# 1      AUS  TAXINCOME     TOT  PC_GDP         A  2016  11.257         NaN
# 2      AUS  TAXINCOME     TOT  PC_GDP         A  2017  11.488         NaN
# 3      AUS  TAXINCOME     TOT  PC_GDP         A  2018  11.786         NaN
# 4      AUT  TAXINCOME     TOT  PC_GDP         A  2015  10.411         NaN

# %%
df3.head()
# Out:
#           Country Alpha-2 code Alpha-3 code Numeric code Latitude (average)  \
# 0     Afghanistan         "AF"        "AFG"          "4"               "33"
# 1         Albania         "AL"        "ALB"          "8"               "41"
# 2         Algeria         "DZ"        "DZA"         "12"               "28"
# 3  American Samoa         "AS"        "ASM"         "16"         "-14.3333"
# 4         Andorra         "AD"        "AND"         "20"             "42.5"
#
#   Longitude (average)
# 0                "65"
# 1                "20"
# 2                 "3"
# 3              "-170"
# 4               "1.6"

# %% [markdown]
# ### Compare perceptions of corruption with happiness score

# %%
x = np.array(df['Score'])
y = np.array(df['Perceptions of corruption'])
z = np.corrcoef(x, y) # Pearson's correlation coefficient
z
# Out:
# array([[1.        , 0.38561307],
#        [0.38561307, 1.        ]])

# %%
z[0,1]
# Out:
# 0.3856130708664785

# %%
z[1,0]
# Out:
# 0.3856130708664785

# %% [markdown]
# #### Pearson's r

# %%
scipy.stats.pearsonr(x, y)
# Out:
# (0.3856130708664786, 6.65401093847035e-07)

# %% [markdown]
# #### Spearman's r

# %%
scipy.stats.spearmanr(x, y)
# Out:
# SpearmanrResult(correlation=0.2173484222491679, pvalue=0.006420238104986938)

# %% [markdown]
# #### Kendall's r

# %%
scipy.stats.kendalltau(x, y)
# Out:
# KendalltauResult(correlation=0.14097398297268365, pvalue=0.00917803290768583)

# %% [markdown]
# #### Using pandas

# %%
a = pd.Series(df['Score'])
b = pd.Series(df['Perceptions of corruption'])
a
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
a.corr(b) # Pearson's
# Out:
# 0.3856130708664785

# %%
a.corr(b, method = 'spearman')
# Out:
# 0.2173484222491679

# %%
a.corr(b, method = 'kendall')
# Out:
# 0.14097398297268365

# %% [markdown]
# #### Using scipy

# %%
result = scipy.stats.linregress(x, y)

# %%
result.slope
# Out:
# 0.03275031380812131

# %%
result.intercept
# Out:
# -0.06648153172658319

# %%
result.rvalue
# Out:
# 0.38561307086647856

# %%
result.pvalue
# Out:
# 6.654010938470404e-07

# %%
result.stderr # standard error of the estimated gradient
# Out:
# 0.006314592484629453

# %% [markdown]
# ### Visualise correlations

# %%
slope, intercept, r, p, stderr = scipy.stats.linregress(x, y)

# %%
line = f'Regression line: y={intercept:.2f}+{slope:.2f}x, r={r:.2f}'
line
# Out:
# 'Regression line: y=-0.07+0.03x, r=0.39'

# %%
fig, ax = plt.subplots()
ax.plot(x, y, linewidth=0, marker='s', label='Data points')
ax.plot(x, intercept + slope * x, label=line)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.legend(facecolor='white')
plt.show()

# %% [markdown]
# Positive correlation, i.e. higher happiness in countries with higher perceptions of corruption!

# %% [markdown]
# #### Produce heatmap

# %%
xy = np.array([x, y])
corr_matrix = np.corrcoef(xy).round(decimals=2)
corr_matrix
# Out:
# array([[1.  , 0.39],
#        [0.39, 1.  ]])

# %%
fig, ax = plt.subplots()
im = ax.imshow(corr_matrix)
im.set_clim(-1, 1)
ax.grid(False)
ax.xaxis.set(ticks=(0, 1), ticklabels=('x', 'y'))
ax.yaxis.set(ticks=(0, 1), ticklabels=('x', 'y'))
ax.set_ylim(2.5, -0.5)
for i in range(2):
    for j in range(2):
        ax.text(j, i, corr_matrix[i, j], ha='center', va='center',
                color='r')
cbar = ax.figure.colorbar(im, ax=ax, format='% .2f')
plt.show()

# %% [markdown]
# ### Use seaborn

# %%
sb.regplot(x = x, y = y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Use pairplot

# %%
sb.pairplot(df, vars = ['Score', 'GDP per capita', 'Social support', 'Healthy life expectancy',
                        'Freedom to make life choices', 'Generosity', 'Perceptions of corruption'])

# %% [markdown]
# #### another heatmap

# %%
plt.figure(figsize=(12, 6))
sb.heatmap(data = df.loc[:,'Score':'Perceptions of corruption'].corr(), cmap = 'coolwarm', annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Happiness is greatly dependent on GDP, social support and life expectancy
